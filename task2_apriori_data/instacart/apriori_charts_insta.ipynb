# %%
from apyori import apriori, dump_as_json, load_transactions
import sys
import matplotlib.pyplot as plt
import time

# %%
def plot_results(minsup_range, runtimes, num_frequent_itemsets, dataset_name):
    plt.figure(figsize=(12, 6))

    # Plot minsup vs. runtime
    plt.subplot(1, 2, 1)
    plt.plot(minsup_range, runtimes, marker='o')
    plt.title('minsup vs. Algorithm Runtime')
    plt.xlabel('minsup')
    plt.ylabel('Runtime (seconds)')

    # Plot minsup vs. number of frequent itemsets
    plt.subplot(1, 2, 2)
    plt.plot(minsup_range, num_frequent_itemsets, marker='o')
    plt.title('minsup vs. Number of Frequent Itemsets')
    plt.xlabel('minsup')
    plt.ylabel('Number of Frequent Itemsets')

    plt.tight_layout()
    
    result_file = f"result_{dataset_name}.png"
    plt.savefig(result_file)
    plt.show()

# %% [markdown]
# ## Initial Testing

# %%
# Results storage
runtimes_range = []
num_frequent_itemsets_range = []

# %%
# minsup_range = [0.001, 0.0008, 0.0006, 0.0004, 0.0002]
# minsup = 0.1%
fileName = "db/instacartNum.txt"
transactions = load_transactions(open(fileName, 'r'), delimiter=',')
minsup = 0.001

print("minsup: " + str(minsup*100) + "%")
print("starting...")
start = time.time()
results = list(apriori(transactions, min_support=minsup))
end = time.time()

print("time taken:" + str(end-start))
print("num itemsets: " + str(len(results)))
runtimes_range.append(end-start)
num_frequent_itemsets_range.append(len(results))

output_file_path = 'output_' + 'instacartNum' + 'point1%.json'
# Clear contents
open(output_file_path, 'w').close()
for record in results:
    # dump_as_json(record, sys.stdout)
    dump_as_json(record, open(output_file_path, 'a'))
# Out:
# minsup: 0.1%
# starting...
# time taken:778.2457656860352
# num itemsets: 3906

# %%
# minsup = 0.08%
fileName = "db/instacartNum.txt"
transactions = load_transactions(open(fileName, 'r'), delimiter=',')

# minsup_range = [0.001, 0.0008, 0.0006, 0.0004, 0.0002]
minsup = 0.0008

print("minsup: " + str(minsup*100) + "%")
print("starting...")
start = time.time()
results = list(apriori(transactions, min_support=minsup))
end = time.time()

print("time taken:" + str(end-start))
print("num itemsets: " + str(len(results)))
runtimes_range.append(end-start)
num_frequent_itemsets_range.append(len(results))

output_file_path = 'output_' + 'instacartNum' + 'point08%.json'
# Clear contents
open(output_file_path, 'w').close()
for record in results:
    # dump_as_json(record, sys.stdout)
    dump_as_json(record, open(output_file_path, 'a'))
# Out:
# minsup: 0.08%
# starting...
# time taken:1130.3119595050812
# num itemsets: 5389

# %%
# minsup = 0.06%
fileName = "db/instacartNum.txt"
transactions = load_transactions(open(fileName, 'r'), delimiter=',')

# minsup_range = [0.001, 0.0008, 0.0006, 0.0004, 0.0002]
minsup = 0.0006

print("minsup: " + str(minsup*100) + "%")
print("starting...")
start = time.time()
results = list(apriori(transactions, min_support=minsup))
end = time.time()

print("time taken:" + str(end-start))
print("num itemsets: " + str(len(results)))
runtimes_range.append(end-start)
num_frequent_itemsets_range.append(len(results))

output_file_path = 'output_' + 'instacartNum' + 'point06%.json'
# Clear contents
open(output_file_path, 'w').close()
for record in results:
    # dump_as_json(record, sys.stdout)
    dump_as_json(record, open(output_file_path, 'a'))
# Out:
# minsup: 0.06%
# starting...
# time taken:1595.5970118045807
# num itemsets: 8133

# %%
# minsup = 0.04%
fileName = "db/instacartNum.txt"
transactions = load_transactions(open(fileName, 'r'), delimiter=',')

# minsup_range = [0.001, 0.0008, 0.0006, 0.0004, 0.0002]
minsup = 0.0004

print("minsup: " + str(minsup*100) + "%")
print("starting...")
start = time.time()
results = list(apriori(transactions, min_support=minsup))
end = time.time()

print("time taken:" + str(end-start))
print("num itemsets: " + str(len(results)))
runtimes_range.append(end-start)
num_frequent_itemsets_range.append(len(results))

output_file_path = 'output_' + 'instacartNum' + 'point04%.json'
# Clear contents
open(output_file_path, 'w').close()
for record in results:
    # dump_as_json(record, sys.stdout)
    dump_as_json(record, open(output_file_path, 'a'))
# Out:
# minsup: 0.04%
# starting...
# time taken:2379.8479113578796
# num itemsets: 14525

# %%
# minsup = 0.02%
fileName = "db/instacartNum.txt"
transactions = load_transactions(open(fileName, 'r'), delimiter=',')

# minsup_range = [0.001, 0.0008, 0.0006, 0.0004, 0.0002]
minsup = 0.0002

print("minsup: " + str(minsup*100) + "%")
print("starting...")
start = time.time()
results = list(apriori(transactions, min_support=minsup))
end = time.time()

print("time taken:" + str(end-start))
print("num itemsets: " + str(len(results)))
runtimes_range.append(end-start)
num_frequent_itemsets_range.append(len(results))

output_file_path = 'output_' + 'instacartNum' + 'point02%.json'
# Clear contents
open(output_file_path, 'w').close()
for record in results:
    # dump_as_json(record, sys.stdout)
    dump_as_json(record, open(output_file_path, 'a'))
# Out:
# minsup: 0.02%
# starting...
# time taken:8484.718655347824
# num itemsets: 39610

# %%
minsup_range = [0.001, 0.0008, 0.0006, 0.0004, 0.0002]
plot_results(minsup_range, runtimes_range, num_frequent_itemsets_range, "instacartNum")

# %% [markdown]
# -------------

# %% [markdown]
# # min-sup Threshold Analysis

# %%
# Results storage
com_runtimes_range = []
com_num_frequent_itemsets_range = []
com_minsup_range = [0.0005, 0.0007, 0.0009, 0.001, 0.005, 0.007, 0.009, 0.01, 0.012, 0.014, 0.016, 0.018, 0.020]

runtimes_range1 = []
num_frequent_itemsets_range1 = []
minsup_range1 = [0.0005, 0.0007, 0.0009, 0.001]

runtimes_range2 = []
num_frequent_itemsets_range2 = []
minsup_range2 = [0.005, 0.007, 0.009, 0.01]

runtimes_range3 = []
num_frequent_itemsets_range3 = []
minsup_range3 = [0.012, 0.014, 0.016, 0.018, 0.020]

# %% [markdown]
# ## range 1 = [0.0005, 0.0007, 0.0009, 0.001]

# %%
# minsup = 0.05%
fileName = "db/instacartNum.txt"
transactions = load_transactions(open(fileName, 'r'), delimiter=',')

# minsup_range = [0.0005, 0.0007, 0.0009, 0.001]
minsup = 0.0005

print("minsup: " + str(minsup*100) + "%")
print("starting...")
start = time.time()
results = list(apriori(transactions, min_support=minsup))
end = time.time()

print("time taken:" + str(end-start))
print("num itemsets: " + str(len(results)))
com_runtimes_range.append(end-start)
com_num_frequent_itemsets_range.append(len(results))
runtimes_range1.append(end-start)
num_frequent_itemsets_range1.append(len(results))

# UNCOMMENT TO CREATE JSON FILE
# output_file_path = 'output_' + 'instacartNum' + 'point05%.json'
# # Clear contents
# open(output_file_path, 'w').close()
# for record in results:
#     # dump_as_json(record, sys.stdout)
#     dump_as_json(record, open(output_file_path, 'a'))
# Out:
# minsup: 0.05%
# starting...
# time taken:2091.42027258873
# num itemsets: 10541

# %%
# minsup = 0.07%
fileName = "db/instacartNum.txt"
transactions = load_transactions(open(fileName, 'r'), delimiter=',')

# minsup_range = [0.0005, 0.0007, 0.0009, 0.001]
minsup = 0.0007

print("minsup: " + str(minsup*100) + "%")
print("starting...")
start = time.time()
results = list(apriori(transactions, min_support=minsup))
end = time.time()

print("time taken:" + str(end-start))
print("num itemsets: " + str(len(results)))
com_runtimes_range.append(end-start)
com_num_frequent_itemsets_range.append(len(results))
runtimes_range1.append(end-start)
num_frequent_itemsets_range1.append(len(results))

# UNCOMMENT TO CREATE JSON FILE
# output_file_path = 'output_' + 'instacartNum' + 'point07%.json'
# # Clear contents
# open(output_file_path, 'w').close()
# for record in results:
#     # dump_as_json(record, sys.stdout)
#     dump_as_json(record, open(output_file_path, 'a'))
# Out:
# minsup: 0.06999999999999999%
# starting...
# time taken:1269.498262166977
# num itemsets: 6522

# %%
# minsup = 0.09%
fileName = "db/instacartNum.txt"
transactions = load_transactions(open(fileName, 'r'), delimiter=',')

# minsup_range = [0.0005, 0.0007, 0.0009, 0.001]
minsup = 0.0009

print("minsup: " + str(minsup*100) + "%")
print("starting...")
start = time.time()
results = list(apriori(transactions, min_support=minsup))
end = time.time()

print("time taken:" + str(end-start))
print("num itemsets: " + str(len(results)))
com_runtimes_range.append(end-start)
com_num_frequent_itemsets_range.append(len(results))
runtimes_range1.append(end-start)
num_frequent_itemsets_range1.append(len(results))

# UNCOMMENT TO CREATE JSON FILE
# output_file_path = 'output_' + 'instacartNum' + 'point09%.json'
# # Clear contents
# open(output_file_path, 'w').close()
# for record in results:
#     # dump_as_json(record, sys.stdout)
#     dump_as_json(record, open(output_file_path, 'a'))
# Out:
# minsup: 0.09%
# starting...
# time taken:889.5534434318542
# num itemsets: 4547

# %%
# minsup = 0.1%
fileName = "db/instacartNum.txt"
transactions = load_transactions(open(fileName, 'r'), delimiter=',')

# minsup_range = [0.0005, 0.0007, 0.0009, 0.001]
minsup = 0.001

print("minsup: " + str(minsup*100) + "%")
print("starting...")
start = time.time()
results = list(apriori(transactions, min_support=minsup))
end = time.time()

print("time taken:" + str(end-start))
print("num itemsets: " + str(len(results)))
com_runtimes_range.append(end-start)
com_num_frequent_itemsets_range.append(len(results))
runtimes_range1.append(end-start)
num_frequent_itemsets_range1.append(len(results))

# UNCOMMENT TO CREATE JSON FILE
# output_file_path = 'output_' + 'instacartNum' + 'point1%.json'
# # Clear contents
# open(output_file_path, 'w').close()
# for record in results:
#     # dump_as_json(record, sys.stdout)
#     dump_as_json(record, open(output_file_path, 'a'))
# Out:
# minsup: 0.1%
# starting...
# time taken:782.6613731384277
# num itemsets: 3906

# %%
# range 1
plot_results(minsup_range1, runtimes_range1, num_frequent_itemsets_range1, "instacart1")

# %% [markdown]
# --------------
# ## range 2 = [0.005, 0.007, 0.009, 0.01]

# %%
# minsup = 0.5%
fileName = "db/instacartNum.txt"
transactions = load_transactions(open(fileName, 'r'), delimiter=',')

# minsup_range = [0.005, 0.007, 0.009, 0.01]
minsup = 0.005

print("minsup: " + str(minsup*100) + "%")
print("starting...")
start = time.time()
results = list(apriori(transactions, min_support=minsup))
end = time.time()

print("time taken:" + str(end-start))
print("num itemsets: " + str(len(results)))
com_runtimes_range.append(end-start)
com_num_frequent_itemsets_range.append(len(results))
runtimes_range2.append(end-start)
num_frequent_itemsets_range2.append(len(results))

# UNCOMMENT TO CREATE JSON FILE
# output_file_path = 'output_' + 'instacartNum' + 'point5%.json'
# # Clear contents
# open(output_file_path, 'w').close()
# for record in results:
#     # dump_as_json(record, sys.stdout)
#     dump_as_json(record, open(output_file_path, 'a'))
# Out:
# minsup: 0.5%
# starting...
# time taken:99.49891805648804
# num itemsets: 328

# %%
# minsup = 0.7%
fileName = "db/instacartNum.txt"
transactions = load_transactions(open(fileName, 'r'), delimiter=',')

# minsup_range = [0.005, 0.007, 0.009, 0.01]
minsup = 0.007

print("minsup: " + str(minsup*100) + "%")
print("starting...")
start = time.time()
results = list(apriori(transactions, min_support=minsup))
end = time.time()

print("time taken:" + str(end-start))
print("num itemsets: " + str(len(results)))
com_runtimes_range.append(end-start)
com_num_frequent_itemsets_range.append(len(results))
runtimes_range2.append(end-start)
num_frequent_itemsets_range2.append(len(results))

# UNCOMMENT TO CREATE JSON FILE
# output_file_path = 'output_' + 'instacartNum' + 'point7%.json'
# # Clear contents
# open(output_file_path, 'w').close()
# for record in results:
#     # dump_as_json(record, sys.stdout)
#     dump_as_json(record, open(output_file_path, 'a'))
# Out:
# minsup: 0.7000000000000001%
# starting...
# time taken:77.71556758880615
# num itemsets: 197

# %%
# minsup = 0.9%
fileName = "db/instacartNum.txt"
transactions = load_transactions(open(fileName, 'r'), delimiter=',')

# minsup_range = [0.005, 0.007, 0.009, 0.01]
minsup = 0.009

print("minsup: " + str(minsup*100) + "%")
print("starting...")
start = time.time()
results = list(apriori(transactions, min_support=minsup))
end = time.time()

print("time taken:" + str(end-start))
print("num itemsets: " + str(len(results)))
com_runtimes_range.append(end-start)
com_num_frequent_itemsets_range.append(len(results))
runtimes_range2.append(end-start)
num_frequent_itemsets_range2.append(len(results))

# UNCOMMENT TO CREATE JSON FILE
# output_file_path = 'output_' + 'instacartNum' + 'point9%.json'
# # Clear contents
# open(output_file_path, 'w').close()
# for record in results:
#     # dump_as_json(record, sys.stdout)
#     dump_as_json(record, open(output_file_path, 'a'))
# Out:
# minsup: 0.8999999999999999%
# starting...
# time taken:62.659196853637695
# num itemsets: 138

# %%
# minsup = 1.0%
fileName = "db/instacartNum.txt"
transactions = load_transactions(open(fileName, 'r'), delimiter=',')

# minsup_range = [0.005, 0.007, 0.009, 0.01]
minsup = 0.01

print("minsup: " + str(minsup*100) + "%")
print("starting...")
start = time.time()
results = list(apriori(transactions, min_support=minsup))
end = time.time()

print("time taken:" + str(end-start))
print("num itemsets: " + str(len(results)))
com_runtimes_range.append(end-start)
com_num_frequent_itemsets_range.append(len(results))
runtimes_range2.append(end-start)
num_frequent_itemsets_range2.append(len(results))

# UNCOMMENT TO CREATE JSON FILE
# output_file_path = 'output_' + 'instacartNum' + '1%.json'
# # Clear contents
# open(output_file_path, 'w').close()
# for record in results:
#     # dump_as_json(record, sys.stdout)
#     dump_as_json(record, open(output_file_path, 'a'))
# Out:
# minsup: 1.0%
# starting...
# time taken:58.008753061294556
# num itemsets: 116

# %%
# range 1
plot_results(minsup_range2, runtimes_range2, num_frequent_itemsets_range2, "instacart2")

# %% [markdown]
# --------------
# ## range 3 = [0.012, 0.014, 0.016, 0.018, 0.020]

# %%
# minsup = 1.2%
fileName = "db/instacartNum.txt"
transactions = load_transactions(open(fileName, 'r'), delimiter=',')

# minsup_range = [0.012, 0.014, 0.016, 0.018, 0.020]
minsup = 0.012

print("minsup: " + str(minsup*100) + "%")
print("starting...")
start = time.time()
results = list(apriori(transactions, min_support=minsup))
end = time.time()

print("time taken:" + str(end-start))
print("num itemsets: " + str(len(results)))
com_runtimes_range.append(end-start)
com_num_frequent_itemsets_range.append(len(results))
runtimes_range3.append(end-start)
num_frequent_itemsets_range3.append(len(results))

# UNCOMMENT TO CREATE JSON FILE
# output_file_path = 'output_' + 'instacartNum' + '1point2%.json'
# # Clear contents
# open(output_file_path, 'w').close()
# for record in results:
#     # dump_as_json(record, sys.stdout)
#     dump_as_json(record, open(output_file_path, 'a'))
# Out:
# minsup: 1.2%
# starting...
# time taken:57.61922764778137
# num itemsets: 91

# %%
# minsup = 1.4%
fileName = "db/instacartNum.txt"
transactions = load_transactions(open(fileName, 'r'), delimiter=',')

# minsup_range = [0.012, 0.014, 0.016, 0.018, 0.020]
minsup = 0.014

print("minsup: " + str(minsup*100) + "%")
print("starting...")
start = time.time()
results = list(apriori(transactions, min_support=minsup))
end = time.time()

print("time taken:" + str(end-start))
print("num itemsets: " + str(len(results)))
com_runtimes_range.append(end-start)
com_num_frequent_itemsets_range.append(len(results))
runtimes_range3.append(end-start)
num_frequent_itemsets_range3.append(len(results))

# UNCOMMENT TO CREATE JSON FILE
# output_file_path = 'output_' + 'instacartNum' + '1point4%.json'
# # Clear contents
# open(output_file_path, 'w').close()
# for record in results:
#     # dump_as_json(record, sys.stdout)
#     dump_as_json(record, open(output_file_path, 'a'))
# Out:
# minsup: 1.4000000000000001%
# starting...
# time taken:51.75277400016785
# num itemsets: 73

# %%
# minsup = 1.6%
fileName = "db/instacartNum.txt"
transactions = load_transactions(open(fileName, 'r'), delimiter=',')

# minsup_range = [0.012, 0.014, 0.016, 0.018, 0.020]
minsup = 0.016

print("minsup: " + str(minsup*100) + "%")
print("starting...")
start = time.time()
results = list(apriori(transactions, min_support=minsup))
end = time.time()

print("time taken:" + str(end-start))
print("num itemsets: " + str(len(results)))
com_runtimes_range.append(end-start)
com_num_frequent_itemsets_range.append(len(results))
runtimes_range3.append(end-start)
num_frequent_itemsets_range3.append(len(results))

# UNCOMMENT TO CREATE JSON FILE
# output_file_path = 'output_' + 'instacartNum' + '1point6%.json'
# # Clear contents
# open(output_file_path, 'w').close()
# for record in results:
#     # dump_as_json(record, sys.stdout)
#     dump_as_json(record, open(output_file_path, 'a'))
# Out:
# minsup: 1.6%
# starting...
# time taken:47.96884846687317
# num itemsets: 60

# %%
# minsup = 1.8%
fileName = "db/instacartNum.txt"
transactions = load_transactions(open(fileName, 'r'), delimiter=',')

# minsup_range = [0.012, 0.014, 0.016, 0.018, 0.020]
minsup = 0.018

print("minsup: " + str(minsup*100) + "%")
print("starting...")
start = time.time()
results = list(apriori(transactions, min_support=minsup))
end = time.time()

print("time taken:" + str(end-start))
print("num itemsets: " + str(len(results)))
com_runtimes_range.append(end-start)
com_num_frequent_itemsets_range.append(len(results))
runtimes_range3.append(end-start)
num_frequent_itemsets_range3.append(len(results))

# UNCOMMENT TO CREATE JSON FILE
# output_file_path = 'output_' + 'instacartNum' + '1point8%.json'
# # Clear contents
# open(output_file_path, 'w').close()
# for record in results:
#     # dump_as_json(record, sys.stdout)
#     dump_as_json(record, open(output_file_path, 'a'))
# Out:
# minsup: 1.7999999999999998%
# starting...
# time taken:49.27078175544739
# num itemsets: 48

# %%
# minsup = 2.0%
fileName = "db/instacartNum.txt"
transactions = load_transactions(open(fileName, 'r'), delimiter=',')

# minsup_range = [0.012, 0.014, 0.016, 0.018, 0.020]
minsup = 0.02

print("minsup: " + str(minsup*100) + "%")
print("starting...")
start = time.time()
results = list(apriori(transactions, min_support=minsup))
end = time.time()

print("time taken:" + str(end-start))
print("num itemsets: " + str(len(results)))
com_runtimes_range.append(end-start)
com_num_frequent_itemsets_range.append(len(results))
runtimes_range3.append(end-start)
num_frequent_itemsets_range3.append(len(results))

# UNCOMMENT TO CREATE JSON FILE
# output_file_path = 'output_' + 'instacartNum' + '2%.json'
# # Clear contents
# open(output_file_path, 'w').close()
# for record in results:
#     # dump_as_json(record, sys.stdout)
#     dump_as_json(record, open(output_file_path, 'a'))
# Out:
# minsup: 2.0%
# starting...
# time taken:44.6499605178833
# num itemsets: 39

# %%
# range only
plot_results(minsup_range3, runtimes_range3, num_frequent_itemsets_range3, "instacart3")

# %%
# combined
com_minsup_range = [0.0005, 0.0007, 0.0009, 0.001, 0.005, 0.007, 0.009, 0.01, 0.012, 0.014, 0.016, 0.018, 0.020]
plot_results(com_minsup_range, com_runtimes_range, com_num_frequent_itemsets_range, "instacart_com")
