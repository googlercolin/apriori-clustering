# %%
from apyori import apriori, dump_as_json, load_transactions
import sys
import matplotlib.pyplot as plt
import time

# %%
def plot_results(minsup_range, runtimes, num_frequent_itemsets, dataset_name):
    plt.figure(figsize=(12, 6))

    # Plot minsup vs. runtime
    plt.subplot(1, 2, 1)
    plt.plot(minsup_range, runtimes, marker='o')
    plt.title('minsup vs. Algorithm Runtime')
    plt.xlabel('minsup')
    plt.ylabel('Runtime (seconds)')

    # Plot minsup vs. number of frequent itemsets
    plt.subplot(1, 2, 2)
    plt.plot(minsup_range, num_frequent_itemsets, marker='o')
    plt.title('minsup vs. Number of Frequent Itemsets')
    plt.xlabel('minsup')
    plt.ylabel('Number of Frequent Itemsets')

    plt.tight_layout()
    
    result_file = f"result_{dataset_name}.png"
    plt.savefig(result_file)
    plt.show()

# %% [markdown]
# ## Initial Testing

# %%
# minsup = 0.1%
fileName = "db/league_filtered.txt"
transactions = load_transactions(open(fileName, 'r'), delimiter=',')

minsup = 0.001

print("minsup: " + str(minsup*100) + "%")
print("starting...")
start = time.time()
results = list(apriori(transactions, min_support=minsup))
end = time.time()

print("time taken:" + str(end-start))
print("num itemsets: " + str(len(results)))
# Out:
# minsup: 0.1%
# starting...
# time taken:552.0296812057495
# num itemsets: 5420

# %%
output_file_path = 'output_' + 'league_filtered' + 'point1%.json'
# Clear contents
open(output_file_path, 'w').close()
for record in results:
    # dump_as_json(record, sys.stdout)
    dump_as_json(record, open(output_file_path, 'a'))

# %%
# minsup = 1%
fileName = "db/league_filtered.txt"
transactions = load_transactions(open(fileName, 'r'), delimiter=',')

minsup = 0.01

print("minsup: " + str(minsup*100) + "%")
print("starting...")
start = time.time()
results = list(apriori(transactions, min_support=minsup))
end = time.time()

print("time taken:" + str(end-start))
print("num itemsets: " + str(len(results)))
# Out:
# minsup: 1.0%
# starting...
# time taken:34.40878367424011
# num itemsets: 387

# %%
output_file_path = 'output_' + 'league_filtered' + '1%.json'
# Clear contents
open(output_file_path, 'w').close()
for record in results:
    # dump_as_json(record, sys.stdout)
    dump_as_json(record, open(output_file_path, 'a'))

# %%
# minsup = 0.5%
fileName = "db/league_filtered.txt"
transactions = load_transactions(open(fileName, 'r'), delimiter=',')

minsup = 0.005

print("minsup: " + str(minsup*100) + "%")
print("starting...")
start = time.time()
results = list(apriori(transactions, min_support=minsup))
end = time.time()

print("time taken:" + str(end-start))
print("num itemsets: " + str(len(results)))
# Out:
# minsup: 0.5%
# starting...
# time taken:68.77363657951355
# num itemsets: 916

# %%
output_file_path = 'output_' + 'league_filtered' + 'point5%.json'
# Clear contents
open(output_file_path, 'w').close()
for record in results:
    # dump_as_json(record, sys.stdout)
    dump_as_json(record, open(output_file_path, 'a'))

# %% [markdown]
# # min-sup Threshold Analysis

# %%
# Results storage
com_runtimes_range = []
com_num_frequent_itemsets_range = []
com_minsup_range = [0.0001, 0.0005, 0.0007, 0.0009, 0.001, 0.005, 0.007, 0.009, 0.01, 0.012, 0.014, 0.016, 0.018, 0.020]

runtimes_range1 = []
num_frequent_itemsets_range1 = []
minsup_range1 = [0.0001, 0.0005, 0.0007, 0.0009, 0.001]

runtimes_range2 = []
num_frequent_itemsets_range2 = []
minsup_range2 = [0.005, 0.007, 0.009, 0.01]

runtimes_range3 = []
num_frequent_itemsets_range3 = []
minsup_range3 = [0.012, 0.014, 0.016, 0.018, 0.020]

# %% [markdown]
# -----
# ## range1
# ### minsup_range1 = [0.0001, 0.0005, 0.0007, 0.0009, 0.001]

# %%
# minsup = 0.01%
fileName = "db/league_filtered.txt"
transactions = load_transactions(open(fileName, 'r'), delimiter=',')

# minsup_range = [0.0001, 0.0005, 0.0007, 0.0009, 0.001]
minsup = 0.0001

print("minsup: " + str(minsup*100) + "%")
print("starting...")
start = time.time()
results = list(apriori(transactions, min_support=minsup))
end = time.time()

print("time taken:" + str(end-start))
print("num itemsets: " + str(len(results)))
com_runtimes_range.append(end-start)
com_num_frequent_itemsets_range.append(len(results))
runtimes_range1.append(end-start)
num_frequent_itemsets_range1.append(len(results))

# UNCOMMENT TO CREATE JSON FILE
# output_file_path = 'output_' + 'league_filtered' + 'point01%.json'
# # Clear contents
# open(output_file_path, 'w').close()
# for record in results:
#     # dump_as_json(record, sys.stdout)
#     dump_as_json(record, open(output_file_path, 'a'))
# Out:
# minsup: 0.01%
# starting...
# time taken:40955.5063662529
# num itemsets: 46536

# %%
# minsup = 0.05%
fileName = "db/league_filtered.txt"
transactions = load_transactions(open(fileName, 'r'), delimiter=',')

# minsup_range = [0.0001, 0.0005, 0.0007, 0.0009, 0.001]
minsup = 0.0005

print("minsup: " + str(minsup*100) + "%")
print("starting...")
start = time.time()
results = list(apriori(transactions, min_support=minsup))
end = time.time()

print("time taken:" + str(end-start))
print("num itemsets: " + str(len(results)))
com_runtimes_range.append(end-start)
com_num_frequent_itemsets_range.append(len(results))
runtimes_range1.append(end-start)
num_frequent_itemsets_range1.append(len(results))

# UNCOMMENT TO CREATE JSON FILE
# output_file_path = 'output_' + 'league_filtered' + 'point05%.json'
# # Clear contents
# open(output_file_path, 'w').close()
# for record in results:
#     # dump_as_json(record, sys.stdout)
#     dump_as_json(record, open(output_file_path, 'a'))
# Out:
# minsup: 0.05%
# starting...
# time taken:1868.9808404445648
# num itemsets: 10879

# %%
# minsup = 0.07%
fileName = "db/league_filtered.txt"
transactions = load_transactions(open(fileName, 'r'), delimiter=',')

# minsup_range = [0.0001, 0.0005, 0.0007, 0.0009, 0.001]
minsup = 0.0007

print("minsup: " + str(minsup*100) + "%")
print("starting...")
start = time.time()
results = list(apriori(transactions, min_support=minsup))
end = time.time()

print("time taken:" + str(end-start))
print("num itemsets: " + str(len(results)))
com_runtimes_range.append(end-start)
com_num_frequent_itemsets_range.append(len(results))
runtimes_range1.append(end-start)
num_frequent_itemsets_range1.append(len(results))

# UNCOMMENT TO CREATE JSON FILE
# output_file_path = 'output_' + 'league_filtered' + 'point07%.json'
# # Clear contents
# open(output_file_path, 'w').close()
# for record in results:
#     # dump_as_json(record, sys.stdout)
#     dump_as_json(record, open(output_file_path, 'a'))
# Out:
# minsup: 0.06999999999999999%
# starting...
# time taken:985.168212890625
# num itemsets: 7837

# %%
# minsup = 0.09%
fileName = "db/league_filtered.txt"
transactions = load_transactions(open(fileName, 'r'), delimiter=',')

# minsup_range = [0.0001, 0.0005, 0.0007, 0.0009, 0.001]
minsup = 0.0009

print("minsup: " + str(minsup*100) + "%")
print("starting...")
start = time.time()
results = list(apriori(transactions, min_support=minsup))
end = time.time()

print("time taken:" + str(end-start))
print("num itemsets: " + str(len(results)))
com_runtimes_range.append(end-start)
com_num_frequent_itemsets_range.append(len(results))
runtimes_range1.append(end-start)
num_frequent_itemsets_range1.append(len(results))

# UNCOMMENT TO CREATE JSON FILE
# output_file_path = 'output_' + 'league_filtered' + 'point09%.json'
# # Clear contents
# open(output_file_path, 'w').close()
# for record in results:
#     # dump_as_json(record, sys.stdout)
#     dump_as_json(record, open(output_file_path, 'a'))
# Out:
# minsup: 0.09%
# starting...
# time taken:693.8900091648102
# num itemsets: 6093

# %%
# minsup = 0.1%
fileName = "db/league_filtered.txt"
transactions = load_transactions(open(fileName, 'r'), delimiter=',')

# minsup_range = [0.0001, 0.0005, 0.0007, 0.0009, 0.001]
minsup = 0.001

print("minsup: " + str(minsup*100) + "%")
print("starting...")
start = time.time()
results = list(apriori(transactions, min_support=minsup))
end = time.time()

print("time taken:" + str(end-start))
print("num itemsets: " + str(len(results)))
com_runtimes_range.append(end-start)
com_num_frequent_itemsets_range.append(len(results))
runtimes_range1.append(end-start)
num_frequent_itemsets_range1.append(len(results))

# UNCOMMENT TO CREATE JSON FILE
# output_file_path = 'output_' + 'league_filtered' + 'point1%.json'
# # Clear contents
# open(output_file_path, 'w').close()
# for record in results:
#     # dump_as_json(record, sys.stdout)
#     dump_as_json(record, open(output_file_path, 'a'))
# Out:
# minsup: 0.1%
# starting...
# time taken:574.7748811244965
# num itemsets: 5420

# %%
# range 1 : with 0.01% 
plot_results(minsup_range1, runtimes_range1, num_frequent_itemsets_range1, "league_filtered1")

# %%
# # range 1 : without 0.01% 
minsup_range1.pop(0)
runtimes_range1.pop(0)
num_frequent_itemsets_range1.pop(0)

plot_results(minsup_range1, runtimes_range1, num_frequent_itemsets_range1, "league_filtered1")

# %%
# adding in 0.0001 & 0.0002 for comparison
print(minsup_range1)
print(runtimes_range1)
print(num_frequent_itemsets_range1)
# Out:
# [0.0005, 0.0007, 0.0009, 0.001]
# [1868.9808404445648, 985.168212890625, 693.8900091648102, 574.7748811244965]
# [10879, 7837, 6093, 5420]

# %%
# insert 0.0002 values (obtained during initial tests)
minsup_range1.insert(0, 0.0002)
runtimes_range1.insert(0, 14365.76868224144)
num_frequent_itemsets_range1.insert(0, 25442)

# insert 0.0001 values (popped out above and re-inserted now)
minsup_range1.insert(0, 0.0001)
runtimes_range1.insert(0, 40955.5063662529)
num_frequent_itemsets_range1.insert(0, 46536)

print(minsup_range1)
print(runtimes_range1)
print(num_frequent_itemsets_range1)
# Out:
# [0.0001, 0.0002, 0.0005, 0.0007, 0.0009, 0.001]
# [40955.5063662529, 14365.76868224144, 1868.9808404445648, 985.168212890625, 693.8900091648102, 574.7748811244965]
# [46536, 25442, 10879, 7837, 6093, 5420]

# %%
# plotting with 0.0001 & 0.0002
plot_results(minsup_range1, runtimes_range1, num_frequent_itemsets_range1, "league_filtered1")

# %% [markdown]
# -----
# ## range 2
# ### minsup_range2 = [0.005, 0.007, 0.009, 0.01]

# %%
# minsup = 0.5%
fileName = "db/league_filtered.txt"
transactions = load_transactions(open(fileName, 'r'), delimiter=',')

# minsup_range = [0.005, 0.007, 0.009, 0.01]
minsup = 0.005

print("minsup: " + str(minsup*100) + "%")
print("starting...")
start = time.time()
results = list(apriori(transactions, min_support=minsup))
end = time.time()

print("time taken:" + str(end-start))
print("num itemsets: " + str(len(results)))
com_runtimes_range.append(end-start)
com_num_frequent_itemsets_range.append(len(results))
runtimes_range2.append(end-start)
num_frequent_itemsets_range2.append(len(results))

# UNCOMMENT TO CREATE JSON FILE
# output_file_path = 'output_' + 'league_filtered' + 'point5%.json'
# # Clear contents
# open(output_file_path, 'w').close()
# for record in results:
#     # dump_as_json(record, sys.stdout)
#     dump_as_json(record, open(output_file_path, 'a'))
# Out:
# minsup: 0.5%
# starting...
# time taken:60.79997110366821
# num itemsets: 916

# %%
# minsup = 0.7%
fileName = "db/league_filtered.txt"
transactions = load_transactions(open(fileName, 'r'), delimiter=',')

# minsup_range = [0.005, 0.007, 0.009, 0.01]
minsup = 0.007

print("minsup: " + str(minsup*100) + "%")
print("starting...")
start = time.time()
results = list(apriori(transactions, min_support=minsup))
end = time.time()

print("time taken:" + str(end-start))
print("num itemsets: " + str(len(results)))
com_runtimes_range.append(end-start)
com_num_frequent_itemsets_range.append(len(results))
runtimes_range2.append(end-start)
num_frequent_itemsets_range2.append(len(results))

# UNCOMMENT TO CREATE JSON FILE
# output_file_path = 'output_' + 'league_filtered' + 'point7%.json'
# # Clear contents
# open(output_file_path, 'w').close()
# for record in results:
#     # dump_as_json(record, sys.stdout)
#     dump_as_json(record, open(output_file_path, 'a'))
# Out:
# minsup: 0.7000000000000001%
# starting...
# time taken:42.099902868270874
# num itemsets: 596

# %%
# minsup = 0.9
fileName = "db/league_filtered.txt"
transactions = load_transactions(open(fileName, 'r'), delimiter=',')

# minsup_range = [0.005, 0.007, 0.009, 0.01]
minsup = 0.009

print("minsup: " + str(minsup*100) + "%")
print("starting...")
start = time.time()
results = list(apriori(transactions, min_support=minsup))
end = time.time()

print("time taken:" + str(end-start))
print("num itemsets: " + str(len(results)))
com_runtimes_range.append(end-start)
com_num_frequent_itemsets_range.append(len(results))
runtimes_range2.append(end-start)
num_frequent_itemsets_range2.append(len(results))

# UNCOMMENT TO CREATE JSON FILE
# output_file_path = 'output_' + 'league_filtered' + 'point9%.json'
# # Clear contents
# open(output_file_path, 'w').close()
# for record in results:
#     # dump_as_json(record, sys.stdout)
#     dump_as_json(record, open(output_file_path, 'a'))
# Out:
# minsup: 0.8999999999999999%
# starting...
# time taken:35.057891845703125
# num itemsets: 437

# %%
# minsup = 1.0%
fileName = "db/league_filtered.txt"
transactions = load_transactions(open(fileName, 'r'), delimiter=',')

# minsup_range = [0.005, 0.007, 0.009, 0.01]
minsup = 0.01

print("minsup: " + str(minsup*100) + "%")
print("starting...")
start = time.time()
results = list(apriori(transactions, min_support=minsup))
end = time.time()

print("time taken:" + str(end-start))
print("num itemsets: " + str(len(results)))
com_runtimes_range.append(end-start)
com_num_frequent_itemsets_range.append(len(results))
runtimes_range2.append(end-start)
num_frequent_itemsets_range2.append(len(results))

# UNCOMMENT TO CREATE JSON FILE
# output_file_path = 'output_' + 'league_filtered' + '1%.json'
# # Clear contents
# open(output_file_path, 'w').close()
# for record in results:
#     # dump_as_json(record, sys.stdout)
#     dump_as_json(record, open(output_file_path, 'a'))
# Out:
# minsup: 1.0%
# starting...
# time taken:35.049705505371094
# num itemsets: 387

# %%
# range only
plot_results(minsup_range2, runtimes_range2, num_frequent_itemsets_range2, "league_filtered2")

# %% [markdown]
# -----
# ## range 3
# ### minsup_range3 = [0.012, 0.014, 0.016, 0.018, 0.020]

# %%
# minsup = 1.2%
fileName = "db/league_filtered.txt"
transactions = load_transactions(open(fileName, 'r'), delimiter=',')

# minsup_range = [0.012, 0.014, 0.016, 0.018, 0.020]
minsup = 0.012

print("minsup: " + str(minsup*100) + "%")
print("starting...")
start = time.time()
results = list(apriori(transactions, min_support=minsup))
end = time.time()

print("time taken:" + str(end-start))
print("num itemsets: " + str(len(results)))
com_runtimes_range.append(end-start)
com_num_frequent_itemsets_range.append(len(results))
runtimes_range3.append(end-start)
num_frequent_itemsets_range3.append(len(results))

# UNCOMMENT TO CREATE JSON FILE
# output_file_path = 'output_' + 'league_filtered' + '1point2%.json'
# # Clear contents
# open(output_file_path, 'w').close()
# for record in results:
#     # dump_as_json(record, sys.stdout)
#     dump_as_json(record, open(output_file_path, 'a'))
# Out:
# minsup: 1.2%
# starting...
# time taken:27.626885652542114
# num itemsets: 303

# %%
# minsup = 1.4%
fileName = "db/league_filtered.txt"
transactions = load_transactions(open(fileName, 'r'), delimiter=',')

# minsup_range = [0.012, 0.014, 0.016, 0.018, 0.020]
minsup = 0.014

print("minsup: " + str(minsup*100) + "%")
print("starting...")
start = time.time()
results = list(apriori(transactions, min_support=minsup))
end = time.time()

print("time taken:" + str(end-start))
print("num itemsets: " + str(len(results)))
com_runtimes_range.append(end-start)
com_num_frequent_itemsets_range.append(len(results))
runtimes_range3.append(end-start)
num_frequent_itemsets_range3.append(len(results))

# UNCOMMENT TO CREATE JSON FILE
# output_file_path = 'output_' + 'league_filtered' + '1point4%.json'
# # Clear contents
# open(output_file_path, 'w').close()
# for record in results:
#     # dump_as_json(record, sys.stdout)
#     dump_as_json(record, open(output_file_path, 'a'))
# Out:
# minsup: 1.4000000000000001%
# starting...
# time taken:21.87977385520935
# num itemsets: 246

# %%
# minsup = 1.6%
fileName = "db/league_filtered.txt"
transactions = load_transactions(open(fileName, 'r'), delimiter=',')

# minsup_range = [0.012, 0.014, 0.016, 0.018, 0.020]
minsup = 0.016

print("minsup: " + str(minsup*100) + "%")
print("starting...")
start = time.time()
results = list(apriori(transactions, min_support=minsup))
end = time.time()

print("time taken:" + str(end-start))
print("num itemsets: " + str(len(results)))
com_runtimes_range.append(end-start)
com_num_frequent_itemsets_range.append(len(results))
runtimes_range3.append(end-start)
num_frequent_itemsets_range3.append(len(results))

# UNCOMMENT TO CREATE JSON FILE
# output_file_path = 'output_' + 'league_filtered' + '1point6%.json'
# # Clear contents
# open(output_file_path, 'w').close()
# for record in results:
#     # dump_as_json(record, sys.stdout)
#     dump_as_json(record, open(output_file_path, 'a'))
# Out:
# minsup: 1.6%
# starting...
# time taken:20.196269035339355
# num itemsets: 212

# %%
# minsup = 1.8%
fileName = "db/league_filtered.txt"
transactions = load_transactions(open(fileName, 'r'), delimiter=',')

# minsup_range = [0.012, 0.014, 0.016, 0.018, 0.020]
minsup = 0.018

print("minsup: " + str(minsup*100) + "%")
print("starting...")
start = time.time()
results = list(apriori(transactions, min_support=minsup))
end = time.time()

print("time taken:" + str(end-start))
print("num itemsets: " + str(len(results)))
com_runtimes_range.append(end-start)
com_num_frequent_itemsets_range.append(len(results))
runtimes_range3.append(end-start)
num_frequent_itemsets_range3.append(len(results))

# UNCOMMENT TO CREATE JSON FILE
# output_file_path = 'output_' + 'league_filtered' + '1point8%.json'
# # Clear contents
# open(output_file_path, 'w').close()
# for record in results:
#     # dump_as_json(record, sys.stdout)
#     dump_as_json(record, open(output_file_path, 'a'))
# Out:
# minsup: 1.7999999999999998%
# starting...
# time taken:18.730592250823975
# num itemsets: 179

# %%
# minsup = 2.0%
fileName = "db/league_filtered.txt"
transactions = load_transactions(open(fileName, 'r'), delimiter=',')

# minsup_range = [0.012, 0.014, 0.016, 0.018, 0.020]
minsup = 0.02

print("minsup: " + str(minsup*100) + "%")
print("starting...")
start = time.time()
results = list(apriori(transactions, min_support=minsup))
end = time.time()

print("time taken:" + str(end-start))
print("num itemsets: " + str(len(results)))
com_runtimes_range.append(end-start)
com_num_frequent_itemsets_range.append(len(results))
runtimes_range3.append(end-start)
num_frequent_itemsets_range3.append(len(results))

# UNCOMMENT TO CREATE JSON FILE
# output_file_path = 'output_' + 'league_filtered' + '2%.json'
# # Clear contents
# open(output_file_path, 'w').close()
# for record in results:
#     # dump_as_json(record, sys.stdout)
#     dump_as_json(record, open(output_file_path, 'a'))
# Out:
# minsup: 2.0%
# starting...
# time taken:17.08638644218445
# num itemsets: 161

# %%
# range 3 only
plot_results(minsup_range3, runtimes_range3, num_frequent_itemsets_range3, "league_filtered3")

# %%
# combined graph
plot_results(com_minsup_range, com_runtimes_range, com_num_frequent_itemsets_range, "league_filtered_com")

# %%
# without 0.0001
com_num_frequent_itemsets_range.pop()
com_runtimes_range.pop()
com_minsup_range.pop()
print(com_num_frequent_itemsets_range)
print(com_runtimes_range)
print(com_minsup_range)

plot_results(com_minsup_range, com_runtimes_range, com_num_frequent_itemsets_range, "league_filtered_com")
# Out:
# [10879, 7837, 6093, 5420, 916, 596, 437, 387, 303, 246, 212, 179, 161]
# [1868.9808404445648, 985.168212890625, 693.8900091648102, 574.7748811244965, 60.79997110366821, 42.099902868270874, 35.057891845703125, 35.049705505371094, 27.626885652542114, 21.87977385520935, 20.196269035339355, 18.730592250823975, 17.08638644218445]
# [0.0005, 0.0007, 0.0009, 0.001, 0.005, 0.007, 0.009, 0.01, 0.012, 0.014, 0.016, 0.018, 0.02]
